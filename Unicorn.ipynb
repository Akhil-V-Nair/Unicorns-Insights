# %%
import pandas as pd
from google.colab import files

# %%
uc = files.upload()
# Out:
#      <input type="file" id="files-12a6635f-859a-4023-bb0c-ac6a9a9dbddc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12a6635f-859a-4023-bb0c-ac6a9a9dbddc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Unicorn_Companies.csv to Unicorn_Companies.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uc['Unicorn_Companies.csv']))

# %%
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %%
df.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Industry', 'City', 'Country',
#        'Continent', 'Year Founded', 'Funding', 'Select Investors'],
#       dtype='object')

# %%
df.duplicated().value_counts()
# Out:
# False    1074
# dtype: int64

# %%
df['Industry'].value_counts()
# Out:
# Fintech                                224
# Internet software & services           205
# E-commerce & direct-to-consumer        111
# Health                                  74
# Artificial intelligence                 73
# Other                                   58
# Supply chain, logistics, & delivery     57
# Cybersecurity                           50
# Data management & analytics             41
# Mobile & telecommunications             38
# Hardware                                34
# Auto & transportation                   31
# Edtech                                  28
# Consumer & retail                       25
# Travel                                  14
# Artificial Intelligence                 11
# Name: Industry, dtype: int64

# %%
#Artificial Intelligence is duplicated.
#Correcting the text value

df['Industry'] = df['Industry'].str.replace('Artificial intelligence', 'Artificial Intelligence', regex=False)

# %%
df['Industry'].value_counts()
# Out:
# Fintech                                224
# Internet software & services           205
# E-commerce & direct-to-consumer        111
# Artificial Intelligence                 84
# Health                                  74
# Other                                   58
# Supply chain, logistics, & delivery     57
# Cybersecurity                           50
# Data management & analytics             41
# Mobile & telecommunications             38
# Hardware                                34
# Auto & transportation                   31
# Edtech                                  28
# Consumer & retail                       25
# Travel                                  14
# Name: Industry, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
df[df['City'].isnull()]
# Out:
#                          Company Valuation Date Joined  \
# 12                           FTX      $32B  2021-07-20
# 170                    HyalRoute       $4B  2020-05-26
# 242                       Moglix       $3B  2021-05-17
# 251                         Trax       $3B  2019-07-22
# 325                  Amber Group       $3B  2021-06-21
# 382                    Ninja Van       $2B  2021-09-27
# 541   Advance Intelligence Group       $2B  2021-09-23
# 811                    Carousell       $1B  2021-09-15
# 848                   Matrixport       $1B  2021-06-01
# 880                     bolttech       $1B  2021-07-01
# 889                        Carro       $1B  2021-06-14
# 893                        Cider       $1B  2021-09-02
# 980                         NIUM       $1B  2021-07-13
# 986                          ONE       $1B  2021-12-08
# 994                      PatSnap       $1B  2021-03-16
# 1061                       WeLab       $1B  2017-11-08
#
# ...

# %%
#replacing the missing cities with their countries
df['City'].fillna(df['Country'],inplace=True)

# %%
df[df['City'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Company, Valuation, Date Joined, Industry, City, Country, Continent, Year Founded, Funding, Select Investors]
# Index: []

# %%
df[df['Select Investors'].isnull()]
# Out:
#               Company Valuation Date Joined                     Industry  \
# 629  LinkSure Network       $1B  2015-01-01  Mobile & telecommunications
#
#          City Country Continent  Year Founded Funding Select Investors
# 629  Shanghai   China      Asia          2013    $52M              NaN

# %%
#Linksure has no Investors. #https://www.cbinsights.com/company/linksure-network/financials this link has the info of the Investors for LinkSure Network.
df['Select Investors'].fillna('Haitong Kaiyuan Investment, Northern Light Venture Capital',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1074 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1074 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
df['Funding'].value_counts()
# Out:
# $1B        60
# $2B        30
# Unknown    12
# $200M      12
# $4B         9
#            ..
# $717M       1
# $101M       1
# $19M        1
# $946M       1
# $620M       1
# Name: Funding, Length: 539, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# United States           562
# China                   173
# India                    65
# United Kingdom           43
# Germany                  26
# France                   24
# Israel                   20
# Canada                   19
# Brazil                   16
# Singapore                12
# South Korea              12
# Australia                 8
# Hong Kong                 6
# Mexico                    6
# Indonesia                 6
# Netherlands               6
# Sweden                    6
# Switzerland               5
# Japan                     5
# Ireland                   5
# Finland                   4
# Norway                    4
# United Arab Emirates      3
# Turkey                    3
# Spain                     3
# Belgium                   3
# Chile                     2
# South Africa              2
# Philippines               2
# Thailand                  2
# Estonia                   2
# Vietnam                   2
# Austria                   2
# ...

# %%
df.isna().sum()
# Out:
# Company             0
# Valuation           0
# Date Joined         0
# Industry            0
# City                0
# Country             0
# Continent           0
# Year Founded        0
# Funding             0
# Select Investors    0
# dtype: int64

# %%
df.dtypes
# Out:
# Company             object
# Valuation           object
# Date Joined         object
# Industry            object
# City                object
# Country             object
# Continent           object
# Year Founded         int64
# Funding             object
# Select Investors    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1074 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1074 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
df['Valuation']=df['Valuation'].str.replace('$','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance      180B  2017-04-07          Artificial Intelligence
# 1     SpaceX      100B  2012-12-01                            Other
# 2      SHEIN      100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe       95B  2014-01-23                          Fintech
# 4     Klarna       46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %%
df['Funding']=df['Funding'].str.replace('$','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance      180B  2017-04-07          Artificial Intelligence
# 1     SpaceX      100B  2012-12-01                            Other
# 2      SHEIN      100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe       95B  2014-01-23                          Fintech
# 4     Klarna       46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012      8B
# 1      Hawthorne  United States  North America          2002      7B
# 2       Shenzhen          China           Asia          2008      2B
# 3  San Francisco  United States  North America          2010      2B
# 4      Stockholm         Sweden         Europe          2005      4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %%
df['number of investors']=df['Select Investors'].str.count(',')+1

# %%
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance      180B  2017-04-07          Artificial Intelligence
# 1     SpaceX      100B  2012-12-01                            Other
# 2      SHEIN      100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe       95B  2014-01-23                          Fintech
# 4     Klarna       46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012      8B
# 1      Hawthorne  United States  North America          2002      7B
# 2       Shenzhen          China           Asia          2008      2B
# 3  San Francisco  United States  North America          2010      2B
# 4      Stockholm         Sweden         Europe          2005      4B
#
#                                     Select Investors  number of investors
# ...

# %%
df['number of investors'].value_counts()
# Out:
# 3    937
# 2     83
# 1     46
# 4      8
# Name: number of investors, dtype: int64

# %%
df[['Investor1','Investor2','Investor3','Investor4']] = df['Select Investors'].str.split(',',expand=True)

# %%
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance      180B  2017-04-07          Artificial Intelligence
# 1     SpaceX      100B  2012-12-01                            Other
# 2      SHEIN      100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe       95B  2014-01-23                          Fintech
# 4     Klarna       46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012      8B
# 1      Hawthorne  United States  North America          2002      7B
# 2       Shenzhen          China           Asia          2008      2B
# 3  San Francisco  United States  North America          2010      2B
# 4      Stockholm         Sweden         Europe          2005      4B
#
#                                     Select Investors  number of investors  \
# ...

# %%
df.index[df['Funding']=='Unknown']
# Out:
# Int64Index([215, 424, 567, 639, 651, 717, 733, 866, 890, 945, 947, 1002], dtype='int64')

# %%
df.drop(df.index[df['Funding']=='Unknown'],inplace=True)

# %%
df.index[df['Funding']=='Unknown']
# Out:
# Int64Index([], dtype='int64')

# %%
df.shape
# Out:
# (1062, 15)

# %%
df[df['Funding']=='0M']
# Out:
#                   Company Valuation Date Joined Industry        City  Country  \
# 189  Otto Bock HealthCare        4B  2017-06-24   Health  Duderstadt  Germany
#
#     Continent  Year Founded Funding Select Investors  number of investors  \
# 189    Europe          1919      0M     EQT Partners                    1
#
#         Investor1 Investor2 Investor3 Investor4
# 189  EQT Partners      None      None      None

# %%
df.at[189,'Funding']='815M'

# %%
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance      180B  2017-04-07          Artificial Intelligence
# 1     SpaceX      100B  2012-12-01                            Other
# 2      SHEIN      100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe       95B  2014-01-23                          Fintech
# 4     Klarna       46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012      8B
# 1      Hawthorne  United States  North America          2002      7B
# 2       Shenzhen          China           Asia          2008      2B
# 3  San Francisco  United States  North America          2010      2B
# 4      Stockholm         Sweden         Europe          2005      4B
#
#                                     Select Investors  number of investors  \
# ...

# %%
df['Date Joined'] = pd.to_datetime(df['Date Joined'])

# %%
df['Unicorn Year']=pd.DatetimeIndex(df['Date Joined']). year

# %%
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance      180B  2017-04-07          Artificial Intelligence
# 1     SpaceX      100B  2012-12-01                            Other
# 2      SHEIN      100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe       95B  2014-01-23                          Fintech
# 4     Klarna       46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012      8B
# 1      Hawthorne  United States  North America          2002      7B
# 2       Shenzhen          China           Asia          2008      2B
# 3  San Francisco  United States  North America          2010      2B
# 4      Stockholm         Sweden         Europe          2005      4B
#
#                                     Select Investors  number of investors  \
# ...

# %%
#We find that the company Yidian Zixun's establishment was in 2021 and the Year it became unicorn was in 2017
df[df['Unicorn Year']<df['Year Founded']]
# Out:
#           Company Valuation Date Joined                     Industry     City  \
# 714  Yidian Zixun        1B  2017-10-17  Mobile & telecommunications  Beijing
#
#     Country Continent  Year Founded Funding  \
# 714   China      Asia          2021    151M
#
#                                    Select Investors  number of investors  \
# 714  Phoenix New Media, Tianjin Haihe Industry Fund                    2
#
#              Investor1                     Investor2 Investor3 Investor4  \
# 714  Phoenix New Media   Tianjin Haihe Industry Fund      None      None
#
#      Unicorn Year
# 714          2017

# %%
#The year Yidian Zixun founded was in 2013 as per https://www.crunchbase.com/organization/yidian-zixun
df.at[714,'Year Founded']=2013

# %%
df[df['Company']=='Yidian Zixun']
# Out:
#           Company Valuation Date Joined                     Industry     City  \
# 714  Yidian Zixun        1B  2017-10-17  Mobile & telecommunications  Beijing
#
#     Country Continent  Year Founded Funding  \
# 714   China      Asia          2013    151M
#
#                                    Select Investors  number of investors  \
# 714  Phoenix New Media, Tianjin Haihe Industry Fund                    2
#
#              Investor1                     Investor2 Investor3 Investor4  \
# 714  Phoenix New Media   Tianjin Haihe Industry Fund      None      None
#
#      Unicorn Year
# 714          2017

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1062 entries, 0 to 1073
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company              1062 non-null   object
#  1   Valuation            1062 non-null   object
#  2   Date Joined          1062 non-null   datetime64[ns]
#  3   Industry             1062 non-null   object
#  4   City                 1062 non-null   object
#  5   Country              1062 non-null   object
#  6   Continent            1062 non-null   object
#  7   Year Founded         1062 non-null   int64
#  8   Funding              1062 non-null   object
#  9   Select Investors     1062 non-null   object
#  10  number of investors  1062 non-null   int64
#  11  Investor1            1062 non-null   object
#  12  Investor2            1020 non-null   object
#  13  Investor3            939 non-null    object
#  14  Investor4            8 non-null      object
# ...

# %%
df.to_csv(r'C:\Users\AkhilVNairNair\Desktop\Data_Science_Project\Unicorn+Companies\cleaned_unicorn.csv', index=False)

# %%
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance      180B  2017-04-07          Artificial Intelligence
# 1     SpaceX      100B  2012-12-01                            Other
# 2      SHEIN      100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe       95B  2014-01-23                          Fintech
# 4     Klarna       46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012      8B
# 1      Hawthorne  United States  North America          2002      7B
# 2       Shenzhen          China           Asia          2008      2B
# 3  San Francisco  United States  North America          2010      2B
# 4      Stockholm         Sweden         Europe          2005      4B
#
#                                     Select Investors  number of investors  \
# ...

# %%
df_1 = df['Investor1'].append(df['Investor2'])

# %%
df_2 = df_1.append(df['Investor3'])

# %%
df_3 = df_2.append(df['Investor4'])

# %%
df_3.isna().sum()
# Out:
# 1219

# %%
df_investors = df_3.unique()

# %%
df_investors = pd.Series(df_investors)

# %%
df_investors.isna().sum()
# Out:
# 1

# %%
df_investors.dropna(inplace=True)

# %%
df_investors.isna().sum()
# Out:
# 0

# %%
df_investors.to_csv('Investors.csv',index=False)

# %% [markdown]
# #The Cleaning Part is Done. We will now move to Power BI to analyze the data.
